# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import seaborn as sns
import math
filename = "example.csv"
names = ['overlap','x','y','z','i','error']
data = pd.read_csv(filename, names=names)

# %%
def toArray(var):
    x = []
    for i in range(len(var)):
        x.append(float(var[i]))
    return np.array(x)

# %%
x = toArray(data.x)
y = toArray(data.y)
z = toArray(data.z)
distance = np.sqrt(x*x+y*y+z*z)
data['distance'] = distance

# %%
data.boxplot()
plt.show()

# %%
data.hist()
plt.show()

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data, alpha=0.2, figsize=(5, 5), diagonal='kde')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-a029f6f12b71> in <module>()
#       1 from pandas.tools.plotting import scatter_matrix
# ----> 2 scatter_matrix(data, alpha=0.2, figsize=(5, 5), diagonal='kde')
#       3 plt.show()
#
# /usr/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in scatter_matrix(frame, alpha, figsize, ax, grid, diagonal, marker, density_kwds, hist_kwds, range_padding, **kwds)
#     299             ax.set_ylabel('')
#     300
# --> 301             _label_axis(ax, kind='x', label=b, position='bottom', rotate=True)
#     302
#     303             _label_axis(ax, kind='y', label=a, position='left')
#
# /usr/lib/python2.7/dist-packages/pandas/tools/plotting.pyc in _label_axis(ax, kind, label, position, ticks, rotate)
#     324         ax.xaxis.set_label_position(position)
#     325         if rotate:
# --> 326             setp(ax.get_xticklabels(), rotation=90)
#     327     elif kind == 'y':
#     328         ax.yaxis.set_visible(True)
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in get_xticklabels(self, minor)
#    2612         """
#    2613         return cbook.silent_list('Text xticklabel',
# -> 2614                                  self.xaxis.get_ticklabels(minor=minor))
#    2615
#    2616     @docstring.dedent_interpd
#
# /usr/lib/pymodules/python2.7/matplotlib/axis.pyc in get_ticklabels(self, minor)
#    1159         if minor:
#    1160             return self.get_minorticklabels()
# -> 1161         return self.get_majorticklabels()
#    1162
#    1163     def get_majorticklines(self):
#
# /usr/lib/pymodules/python2.7/matplotlib/axis.pyc in get_majorticklabels(self)
#    1143     def get_majorticklabels(self):
#    1144         'Return a list of Text instances for the major ticklabels'
# -> 1145         ticks = self.get_major_ticks()
#    1146         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1147         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# /usr/lib/pymodules/python2.7/matplotlib/axis.pyc in get_major_ticks(self, numticks)
#    1246             # update the new tick label properties from the old
#    1247             for i in range(numticks - len(self.majorTicks)):
# -> 1248                 tick = self._get_tick(major=True)
#    1249                 self.majorTicks.append(tick)
#    1250
#
# /usr/lib/pymodules/python2.7/matplotlib/axis.pyc in _get_tick(self, major)
#    1607         else:
#    1608             tick_kw = self._minor_tick_kw
# -> 1609         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1610
#    1611     def _get_label(self):
#
# /usr/lib/pymodules/python2.7/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     140         self.tick1line = self._get_tick1line()
#     141         self.tick2line = self._get_tick2line()
# --> 142         self.gridline = self._get_gridline()
#     143
#     144         self.label1 = self._get_text1()
#
# /usr/lib/pymodules/python2.7/matplotlib/axis.pyc in _get_gridline(self)
#     414                    linewidth=rcParams['grid.linewidth'],
#     415                    alpha=rcParams['grid.alpha'],
# --> 416                    markersize=0
#     417                    )
#     418         l.set_transform(self.axes.get_xaxis_transform(which='grid'))
#
# /usr/lib/pymodules/python2.7/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     209         self.set_color(color)
#     210         self._marker = MarkerStyle()
# --> 211         self.set_marker(marker)
#     212         self.set_markevery(markevery)
#     213         self.set_antialiased(antialiased)
#
# /usr/lib/pymodules/python2.7/matplotlib/lines.pyc in set_marker(self, marker)
#     851
#     852         """
# --> 853         self._marker.set_marker(marker)
#     854
#     855     def set_markeredgecolor(self, ec):
#
# /usr/lib/pymodules/python2.7/matplotlib/markers.pyc in set_marker(self, marker)
#     217
#     218     def set_marker(self, marker):
# --> 219         if (iterable(marker) and len(marker) in (2, 3) and
#     220                 marker[1] in (0, 1, 2, 3)):
#     221             self._marker_function = self._set_tuple_marker
#
# /usr/lib/pymodules/python2.7/matplotlib/cbook.pyc in iterable(obj)
#     660     'return true if *obj* is iterable'
#     661     try:
# --> 662         iter(obj)
#     663     except TypeError:
#     664         return False
#
# KeyboardInterrupt:

# %%
g = sns.PairGrid(data)
g.map(plt.scatter);

# %%
plt.scatter(data['distance'], data['error']);
